# %%
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("API_FOOTBALL_KEY")

# %%
# Find the FIFA World Cup league ID

import requests
import os

headers = {
    "x-apisports-key": os.environ["API_FOOTBALL_KEY"]
}

response = requests.get(
    "https://v3.football.api-sports.io/leagues",
    headers=headers,
    params={"search": "World Cup"},
)

response.raise_for_status()

for league in response.json()["response"]:
    print(
        league["league"]["id"],
        league["league"]["name"],
        league["country"]["name"],
    )
# Out:
# 1 World Cup World
# 8 World Cup - Women World
# 15 FIFA Club World Cup World
# 37 World Cup - Qualification Intercontinental Play-offs World
# 490 World Cup - U20 World
# 31 World Cup - Qualification CONCACAF World
# 32 World Cup - Qualification Europe World
# 33 World Cup - Qualification Oceania World
# 34 World Cup - Qualification South America World
# 29 World Cup - Qualification Africa World
# 30 World Cup - Qualification Asia World
# 587 World Cup - U17 World
# 920 World Cup - U20 - Women World
# 927 World Cup - Women - Qualification Concacaf World
# 950 World Cup - U17 - Women World
# 880 World Cup - Women - Qualification Europe World
# 1186 FIFA Club World Cup - Play-In World
# 1213 Kings World Cup Nations World

# %%
# Find all the team ids

BASE_URL = "https://v3.football.api-sports.io"

response = requests.get(
    f"{BASE_URL}/teams",
    headers=headers,
    params={
        "league": 1,      # FIFA World Cup
        "season": 2026,
    },
    timeout=30,
)

response.raise_for_status()

data = response.json()

print(f"Found {data['results']} teams\n")

for item in sorted(data["response"], key=lambda x: x["team"]["name"]):
    team = item["team"]

    print(
        f"{team['id']:>4} | "
        f"{team['name']:<25} | "
        f"{team['country']}"
    )
# Out:
# Found 48 teams
#
# 1532 | Algeria                   | Algeria
#   26 | Argentina                 | Argentina
#   20 | Australia                 | Australia
#  775 | Austria                   | Austria
#    1 | Belgium                   | Belgium
# 1113 | Bosnia & Herzegovina      | Bosnia
#    6 | Brazil                    | Brazil
# 5529 | Canada                    | Canada
# 1533 | Cape Verde Islands        | Cape-Verde-Islands
#    8 | Colombia                  | Colombia
# 1508 | Congo DR                  | Congo-DR
#    3 | Croatia                   | Croatia
# 5530 | Curaçao                   | Curacao
#  770 | Czechia                   | Czech-Republic
# 2382 | Ecuador                   | Ecuador
#   32 | Egypt                     | Egypt
#   10 | England                   | England
#    2 | France                    | France
#   25 | Germany                   | Germany
# 1504 | Ghana                     | Ghana
# 2386 | Haiti                     | Haiti
#   22 | Iran                      | Iran
# 1567 | Iraq                      | Iraq
# 1501 | Ivory Coast               | Ivory-Coast
#   12 | Japan                     | Japan
# 1548 | Jordan                    | Jordan
#   16 | Mexico                    | Mexico
#   31 | Morocco                   | Morocco
# 1118 | Netherlands               | Netherlands
# 4673 | New Zealand               | New-Zealand
# 1090 | Norway                    | Norway
#   11 | Panama                    | Panama
# 2380 | Paraguay                  | Paraguay
#   27 | Portugal                  | Portugal
# 1569 | Qatar                     | Qatar
#   23 | Saudi Arabia              | Saudi-Arabia
# 1108 | Scotland                  | Scotland
#   13 | Senegal                   | Senegal
# 1531 | South Africa              | South-Africa
#   17 | South Korea               | South-Korea
#    9 | Spain                     | Spain
#    5 | Sweden                    | Sweden
#   15 | Switzerland               | Switzerland
#   28 | Tunisia                   | Tunisia
#  777 | Türkiye                   | Turkey
# 2384 | USA                       | USA
#    7 | Uruguay                   | Uruguay
# 1568 | Uzbekistan                | Uzbekistan

# %%
# Find the team ID for Argentian and Spain
team_ids = {
    team["team"]["name"]: team["team"]["id"]
    for team in data["response"]
}

print(team_ids["Argentina"])
print(team_ids["Spain"])
# Out:
# 26
# 9

# %%
# Get Argentina's squad

TEAM_ID = team_ids["Argentina"]  # Replace with the ID returned above


response = requests.get(
    "https://v3.football.api-sports.io/players/squads",
    headers=headers,
    params={
        "team": TEAM_ID,
    },
)

response.raise_for_status()

data = response.json()

for squad in data["response"]:
    print(f"\n{squad['team']['name']}")
    print("-" * 40)

    for player in squad["players"]:
        print(
            f"{player['id']:>5} | "
            f"{player['name']:<30} | "
            f"{player['position']}"
        )
# Out:
# Argentina
# ----------------------------------------
# 19599 | E. Martínez                    | Goalkeeper
#  2465 | J. Musso                       | Goalkeeper
# 47296 | G. Rulli                       | Goalkeeper
#  2467 | Lisandro Martínez              | Defender
#  6231 | F. Medina                      | Defender
#  6503 | N. Molina                      | Defender
#  2468 | G. Montiel                     | Defender
#   624 | N. Otamendi                    | Defender
# 30776 | C. Romero                      | Defender
#   529 | N. Tagliafico                  | Defender
# 319572 | V. Barco                       | Midfielder
#  5996 | E. Fernández                   | Midfielder
#  1578 | G. Lo Celso                    | Midfielder
#  6716 | A. Mac Allister                | Midfielder
#  6002 | E. Palacios                    | Defender
#   271 | L. Paredes                     | Midfielder
# 26315 | N. González                    | Attacker
#  2472 | R. De Paul                     | Midfielder
#  6067 | T. Almada                      | Midfielder
#  6009 | J. Álvarez                     | Midfielder
# 350037 | N. Paz                         | Attacker
# 295513 | J. López                       | Attacker
#   217 | Lautaro Martínez               | Attacker
#   154 | L. Messi                       | Attacker
# 323935 | G. Simeone                     | Midfielder
#  6610 | M. Senesi                      | Midfielder

# %%
# get Lionel Messi's player statistics

MESSI_PLAYER_ID = 154 

response = requests.get(
    "https://v3.football.api-sports.io/players",
    headers=headers,
    params={
        "id": MESSI_PLAYER_ID,
        "season": 2026,
    },
)

response.raise_for_status()

data = response.json()

for player in data["response"]:
    p = player["player"]
    stats = player["statistics"][0]

    print("=" * 60)
    print(f"Name       : {p['name']}")
    print(f"Player ID  : {p['id']}")
    print(f"Nationality: {p['nationality']}")
    print(f"Age        : {p['age']}")
    print(f"Team       : {stats['team']['name']}")
    print(f"Position   : {stats['games']['position']}")
    print(f"Appearances: {stats['games']['appearences']}")
    print(f"Minutes    : {stats['games']['minutes']}")
    print(f"Rating     : {stats['games']['rating']}")
    print(f"Goals      : {stats['goals']['total']}")
    print(f"Assists    : {stats['goals']['assists']}")
    print(f"Shots      : {stats['shots']['total']}")
    print(f"Shots OT   : {stats['shots']['on']}")
    print(f"Passes     : {stats['passes']['total']}")
    print(f"Key Passes : {stats['passes']['key']}")
    print(f"Pass %     : {stats['passes']['accuracy']}")
# Out:
# ============================================================
# Name       : L. Messi
# Player ID  : 154
# Nationality: Argentina
# Age        : 38
# Team       : Argentina
# Position   : Attacker
# Appearances: 12
# Minutes    : 956
# Rating     : 8.03
# Goals      : 8
# Assists    : 3
# Shots      : 30
# Shots OT   : 20
# Passes     : 561
# Key Passes : 25
# Pass %     : None
